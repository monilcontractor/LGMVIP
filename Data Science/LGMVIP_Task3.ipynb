# %% [markdown]
# # **LetsGrowMore - Data Science**
#
# **Task 3 :- Image To Pencil Sketch With Python**
#
# **Name :- Monil Nareshbhai Contractor**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image=cv2.imread("/content/drive/MyDrive/Colab Notebooks/dog.jpeg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=474x316 at 0x7F8BF4A7F690>

# %%
#grayscale image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=474x316 at 0x7F8BF4A10150>

# %%
#negative image
inverted_image=255-gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=474x316 at 0x7F8BF4A10B10>

# %%
#blur image
blurred=cv2.GaussianBlur(inverted_image,(21,21),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=474x316 at 0x7F8BF4A15690>

# %%
inverted_blurred=255-blurred
pencil_sketch=cv2.divide(gray_image,inverted_blurred,scale=256.0)
#Original image
cv2_imshow(image)
#pencil sketch
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=474x316 at 0x7F8BF4A1BD10>
# <PIL.Image.Image image mode=L size=474x316 at 0x7F8BF4A1B490>
